# %% [markdown]
# # Collecting Rent Offers from Daft.ie website

# %% [markdown]
# Install dependencies

# %%
#%pip install bs4 lxml requests-cache tqdm > /dev/null

# %%
import datetime
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests_cache
import warnings
import bs4
from tqdm import tqdm
import re


warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
daft_base_url = 'https://www.daft.ie'

# %%
session = requests_cache.CachedSession(
  '.daft_cache',
  use_cache_dir=True,
  cache_control=False,
  expire_after=datetime.timedelta(days=30),
  allowable_methods=['GET'],
  allowable_codes=[200],
  stale_if_error=True
)

# %% [markdown]
# Get frontpage with all listings

# %%
def get_page(url):
    r = session.get(url)
    soup = bs4.BeautifulSoup(r.text, 'html.parser')
    data_script = soup.find('script', id='__NEXT_DATA__', type='application/json')
    if data_script:
        return json.loads(data_script.text)
    return None


def get_listing_page(page_number):
    url = f'{daft_base_url}/property-for-rent/ireland?from={page_number*20}&pageSize=20'
    return get_page(url)

# %%
first_page_data = get_listing_page(0)
total_pages = first_page_data['props']['pageProps']['paging']['totalPages']
total_pages
# Out:
# 40

# %%
data = {
    0: first_page_data
}

# %%
for i in tqdm(range(1, total_pages)):
    data[i] = get_listing_page(i)
# Out:
# 100%|██████████| 39/39 [00:03<00:00, 10.24it/s]

# %%
df = pd.DataFrame()

for item in data.values():
    if 'listings' not in item['props']['pageProps']:
        continue
    for listing in item['props']['pageProps']['listings']:
        df = df.append(listing['listing'], ignore_index=True)

# %%
df = df.convert_dtypes()
df = df.set_index('id')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 798 entries, 3581863 to 3175844
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              798 non-null    string
#  1   seoTitle           798 non-null    string
#  2   sections           798 non-null    object
#  3   saleType           798 non-null    object
#  4   featuredLevel      798 non-null    string
#  5   featuredLevelFull  798 non-null    string
#  6   publishDate        798 non-null    Int64
#  7   price              798 non-null    string
#  8   abbreviatedPrice   798 non-null    string
#  9   numBedrooms        760 non-null    string
#  10  propertyType       798 non-null    string
#  11  daftShortcode      798 non-null    string
#  12  seller             798 non-null    object
#  13  media              798 non-null    object
#  14  ber                694 non-null    object
#  15  platform           798 non-null    string
#  16  point              798 non-null    object
#  17  seoFriendlyPath    798 non-null    string
#  18  prs                17 non-null     object
#  19  pageBranding       278 non-null    object
#  20  category           798 non-null    string
#  21  state              798 non-null    string
#  22  premierPartner     798 non-null    boolean
#  23  numBathrooms       745 non-null    string
#  24  sticker            2 non-null      string
#  25  priceHistory       9 non-null      object
#  26  openViewings       3 non-null      object
#  27  label              1 non-null      string
# dtypes: Int64(1), boolean(1), object(10), string(16)
# memory usage: 177.7+ KB

# %%
df_details = pd.DataFrame()

for index, values in tqdm(df.iterrows()):
    url = daft_base_url + values.seoFriendlyPath
    r = get_page(url)
    if not r:
        print(f'No response from {url}')
        continue

    page_props = r['props']['pageProps']

    def add_item(item):
        global df_details
        if 'listingViews' in page_props:
            item['listingViews'] = page_props['listingViews']
        else:
            item['listingViews'] = 0

        df_details = df_details.append(item, ignore_index=True)

    # page with only one listing
    if 'listing' in page_props:
        item = page_props['listing']
        add_item(item)

    # page with multiple listings
    elif 'listings' in page_props:
        for item in page_props['listings']:
            add_item(item)
# Out:
# 798it [00:31, 25.27it/s]

# %%
df_details['id'] = df_details['id'].astype(df.index.dtype)

# %%
df_details = df_details.set_index('id')
df_details.head()
# Out:
#                                                      title  \
# id
# 3581863     The Benson, The Benson, Britain Quay, Dublin 2
# 1442724       Opus, 6 Hanover Quay, Hanover Quay, Dublin 2
# 1446982        Quayside Quarter, North Wall Quay, Dublin 1
# 3523580  Griffith Wood, Griffith Avenue, Drumcondra, Du...
# 3652525  Hali, Cherrywood, Dublin 18, Cherrywood, Co. D...
#
#                                                   seoTitle  \
# id
# 3581863     The Benson, The Benson, Britain Quay, Dublin 2
# 1442724       Opus, 6 Hanover Quay, Hanover Quay, Dublin 2
# 1446982        Quayside Quarter, North Wall Quay, Dublin 1
# 3523580  Griffith Wood, Griffith Avenue, Drumcondra, Du...
# 3652525  Hali, Cherrywood, Dublin 18, Cherrywood, Co. D...
#
#                                               sections featuredLevel  \
# id
# 3581863  [Property, Private Rental Sector, Apartments]      FEATURED
# 1442724  [Property, Private Rental Sector, Apartments]      FEATURED
# 1446982  [Property, Private Rental Sector, Apartments]      FEATURED
# 3523580  [Property, Private Rental Sector, Apartments]      FEATURED
# 3652525  [Property, Private Rental Sector, Apartments]      FEATURED
#
#         featuredLevelFull lastUpdateDate                  price   numBedrooms  \
# id
# 3581863     FEATURED_PLUS     14/09/2022  From €3,300 per month     2 & 3 bed
# 1442724     FEATURED_PLUS     14/09/2022  From €6,222 per month     3 & 4 bed
# 1446982          FEATURED     09/09/2022  From €2,710 per month  1, 2 & 3 bed
# 3523580          FEATURED     09/09/2022  From €2,445 per month     2 & 3 bed
# 3652525          FEATURED     07/09/2022  From €1,660 per month  1, 2 & 3 bed
#
#         propertyType daftShortcode  ...  \
# id                                  ...
# 3581863   Apartments      96577784  ...
# 1442724   Apartments       9161879  ...
# 1446982   Apartments       9162471  ...
# 3523580   Apartments      96115505  ...
# 3652525   Apartments      97315531  ...
#
#                                                   features  \
# id
# 3581863  [Open plan living / dining area , Floor to cei...
# 1442724  [Spacious and bright entrance lobby where you ...
# 1446982  [Concierge 24/7 and Resident Gym , Luxury wate...
# 3523580                            [Brand new development]
# 3652525  [Open plan living, Fully furnished, High spec ...
#
#                               nonFormatted listingViews listing savedAd  \
# id
# 3581863  {'price': 3300, 'section': 'prs'}       100212     NaN     NaN
# 1442724  {'price': 6222, 'section': 'prs'}       369602     NaN     NaN
# 1446982  {'price': 2710, 'section': 'prs'}      1326024     NaN     NaN
# 3523580  {'price': 2445, 'section': 'prs'}       264646     NaN     NaN
# 3652525  {'price': 1660, 'section': 'prs'}         8387     NaN     NaN
#
#         numBathrooms priceHistory propertyOverview openViewings label
# id
# 3581863          NaN          NaN              NaN          NaN   NaN
# 1442724          NaN          NaN              NaN          NaN   NaN
# 1446982          NaN          NaN              NaN          NaN   NaN
# 3523580          NaN          NaN              NaN          NaN   NaN
# 3652525          NaN          NaN              NaN          NaN   NaN
#
# [5 rows x 35 columns]

# %%
detail_only_columns = [c for c in df_details.columns.tolist() if c not in df.columns.tolist()]
detail_only_columns
# Out:
# ['lastUpdateDate',
#  'description',
#  'primaryAreaId',
#  'isInRepublicOfIreland',
#  'facilities',
#  'features',
#  'nonFormatted',
#  'listingViews',
#  'listing',
#  'savedAd',
#  'propertyOverview']

# %% [markdown]
# Join new columns comming from detailed page.

# %%
df = df.join(df_details[detail_only_columns])

# %% [markdown]
# ### Expand fields to create new features

# %%
def fix_case(col, prefix=''):
    # remove all spaces
    col = col.strip().replace(' ', '')

    # make sure that first letter is lowercase
    col = col[0].lower() + col[1:]

    # replace uppercase letters with _ + lowercase
    col = ''.join([
        '_' + l.lower() if l.isupper() else l for l in col])

    fixed_name = prefix + col

    # simple fix to avoid double underscores in column names
    return fixed_name.replace('__', '_')

# %%
def standarize_columns(df, orig):
    cols = df.columns.tolist()
    new_columns = [fix_case(orig + x) for x in cols]
    df.columns = new_columns
    return df

# %%
def join(df1, df2):
    if df2.shape[0] > df1.shape[0]:
        raise Exception('Right data frame is bigger than left')
    for col in df2.columns.tolist():
        df1[col] = df2[col]
    return df1

# %%
def prepare(df, col):
    df.columns = [fix_case(x, col + '_') for x in df.columns.tolist()]
    return df.dropna(axis=1, how='any', thresh=df.shape[0]*.3)

# %%
df.columns = [fix_case(c) for c in df.columns.tolist()]

# %% [markdown]
# **section**

# %%
# %%time
all_sections = df['sections'].explode().unique().tolist()
all_sections
# Out:
# CPU times: user 1.85 ms, sys: 926 µs, total: 2.77 ms
# Wall time: 2.05 ms
# ['Property',
#  'Residential',
#  'Apartment',
#  'Private Rental Sector',
#  'Apartments',
#  'Studio Apartment',
#  'House',
#  'Flat']

# %%
def row_to_column(df, col, options):
    df_options = pd.DataFrame(columns=options, index=df.index)
    for option in options:
        df_options[option] = df[col].apply(lambda p: 1 if option in p else 0)
    return standarize_columns(df_options, col)

# %%
# %%time

df_sections = row_to_column(df, 'sections', all_sections)
df_sections.head()
# Out:
# CPU times: user 8.16 ms, sys: 1.01 ms, total: 9.17 ms
# Wall time: 8.48 ms
#          sections_property  sections_residential  sections_apartment  \
# id
# 152700                   1                     1                   1
# 1442724                  1                     0                   0
# 1443907                  1                     0                   0
# 1446982                  1                     0                   0
# 1527608                  1                     0                   0
#
#          sections_private_rental_sector  sections_apartments  \
# id
# 152700                                0                    0
# 1442724                               1                    1
# 1443907                               1                    1
# 1446982                               1                    1
# 1527608                               1                    1
#
#          sections_studio_apartment  sections_house  sections_flat
# id
# 152700                           0               0              0
# 1442724                          0               0              0
# 1443907                          0               0              0
# 1446982                          0               0              0
# 1527608                          0               0              0

# %%
df = df.join(df_sections)
df.head()
# Out:
#                                                      title  \
# id
# 152700   Serviced Apartments in Malahide, Malahide, Co....
# 1442724       Opus, 6 Hanover Quay, Hanover Quay, Dublin 2
# 1443907     Capital Dock Residence, Grand Canal , Dublin 2
# 1446982        Quayside Quarter, North Wall Quay, Dublin 1
# 1527608    Node Living, 25 pembroke street upper, Dublin 2
#
#                                                  seo_title  \
# id
# 152700   Serviced Apartments in Malahide, Malahide, Co....
# 1442724       Opus, 6 Hanover Quay, Hanover Quay, Dublin 2
# 1443907     Capital Dock Residence, Grand Canal , Dublin 2
# 1446982        Quayside Quarter, North Wall Quay, Dublin 1
# 1527608    Node Living, 25 pembroke street upper, Dublin 2
#
#                                               sections sale_type  \
# id
# 152700              [Property, Residential, Apartment]  [To Let]
# 1442724  [Property, Private Rental Sector, Apartments]  [To Let]
# 1443907  [Property, Private Rental Sector, Apartments]  [To Let]
# 1446982  [Property, Private Rental Sector, Apartments]  [To Let]
# 1527608  [Property, Private Rental Sector, Apartments]  [To Let]
#
#         featured_level featured_level_full   publish_date  \
# id
# 152700        FEATURED            FEATURED  1663152762654
# 1442724       FEATURED       FEATURED_PLUS  1663166461000
# 1443907        PREMIUM             PREMIUM  1660298367000
# 1446982       FEATURED            FEATURED  1662738980000
# 1527608       FEATURED            FEATURED  1660573247000
#
#                           price abbreviated_price  num_bedrooms  ... saved_ad  \
# id                                                               ...
# 152700            €980 per week              €980         2 Bed  ...      NaN
# 1442724   From €6,222 per month           €6,220+     3 & 4 bed  ...      NaN
# 1443907  From €10,440 per month           €10,440         2 bed  ...      NaN
# 1446982   From €2,710 per month           €2,710+  1, 2 & 3 bed  ...      NaN
# 1527608   From €4,039 per month            €4,040         2 bed  ...      NaN
#
#                                          property_overview sections_property  \
# id
# 152700   [{'label': 'Double Bedroom', 'text': '2'}, {'l...                 1
# 1442724                                                NaN                 1
# 1443907                                                NaN                 1
# 1446982                                                NaN                 1
# 1527608                                                NaN                 1
#
#         sections_residential sections_apartment  \
# id
# 152700                     1                  1
# 1442724                    0                  0
# 1443907                    0                  0
# 1446982                    0                  0
# 1527608                    0                  0
#
#         sections_private_rental_sector sections_apartments  \
# id
# 152700                               0                   0
# 1442724                              1                   1
# 1443907                              1                   1
# 1446982                              1                   1
# 1527608                              1                   1
#
#         sections_studio_apartment sections_house sections_flat
# id
# 152700                          0              0             0
# 1442724                         0              0             0
# 1443907                         0              0             0
# 1446982                         0              0             0
# 1527608                         0              0             0
#
# [5 rows x 47 columns]

# %% [markdown]
# **saleType**

# %%
all_sale_types = df['sale_type'].explode().unique()
all_sale_types
# Out:
# array(['To Let'], dtype=object)

# %%
# %%time

df_sale_type = row_to_column(df, 'sale_type', all_sale_types)
df_sale_type.head()
# Out:
# CPU times: user 2.64 ms, sys: 524 µs, total: 3.16 ms
# Wall time: 2.84 ms
#          sale_type_to_let
# id
# 152700                  1
# 1442724                 1
# 1443907                 1
# 1446982                 1
# 1527608                 1

# %%
df = join(df, df_sale_type)

# %% [markdown]
# **publish_date**

# %%
df['publish_date'] = pd.to_datetime(df['publish_date'], unit='ms')

# %% [markdown]
# **price**

# %%
df_price = pd.DataFrame(index=df.index)
df_price['is_price_weekly'] = df['price'].apply(lambda s: 1 if 'week' in s else 0)
df_price['is_price_monthly'] = df['price'].apply(lambda s: 1 if 'month' in s else 0)
df_price['is_price_on_application'] = df['price'].apply(lambda s: 1 if 'Price on Application' in s else 0)

# %%
# %%time

euro_cost = re.compile(r"€(\d*),?(\d+)")

df_price['price_as_int'] = df['price'].apply(
    lambda s: int(''.join(euro_cost.findall(s)[0])) if euro_cost.search(s) else 0)
# Out:
# CPU times: user 2.22 ms, sys: 67 µs, total: 2.29 ms
# Wall time: 2.26 ms

# %%
df_price['monthly_price'] = (
    df_price['price_as_int'] * (4 * df_price['is_price_weekly'])) + (
        df_price['price_as_int'] * df_price['is_price_monthly'])

# %%
df = join(df, df_price)

# %% [markdown]
# **num_bedrooms & num_bathrooms**

# %%
numbers = re.compile(r"(\d+)\D+")

def extract_numbers(col):
    df_temp = pd.DataFrame(index=df.index)
    return df.fillna('')[col].apply(numbers.findall)

# %%
df['num_bedrooms_as_list'] = extract_numbers('num_bedrooms')

# %%
df['num_bathrooms_as_list'] = extract_numbers('num_bathrooms')

# %% [markdown]
# **seller**

# %%
# %%time
df_seller = pd.DataFrame(columns=df['seller'].iloc[0].keys(), index=df.index)
for index, item in zip(df['seller'].index, df['seller'].tolist()):
    for col, value in item.items():
        df_seller.loc[index, col] = value
# Out:
# CPU times: user 617 ms, sys: 10.5 ms, total: 627 ms
# Wall time: 642 ms

# %%
df_seller.columns = [fix_case(c, 'seller_') for c in df_seller.columns]

# %%
df = join(df, df_seller)

# %% [markdown]
# **media**

# %%
from collections import defaultdict

def iterate_over_struct(fn, index, item, root):
    item_type = type(item)
    if item_type == dict:
        for key, value in item.items():
            iterate_over_struct(fn, index, value, root + [key])
    elif item_type == list:
        for index_value, value in enumerate(item):
            iterate_over_struct(fn, index, value, root + [index_value])
    else:
        path = [str(r) for r in root if r]
        col = '_'.join(path)
        col = fix_case(col)
        fn(index, col, item)

def make_flat(df, col):
    final = defaultdict(dict)

    def add_to_list(index, col, value):
        final[index][col] = value

    for index, line in zip(df.index.tolist(), df[col]):
        iterate_over_struct(add_to_list, index, line, [col])

    df_new = pd.DataFrame(final.values(), index=final.keys())
    return df_new

# %%
df_medias = make_flat(df, 'media')
df_medias.head()
# Out:
#                                   media_images_size720x480  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#                                   media_images_size600x600  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#                                   media_images_size400x300  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#                                   media_images_size360x240  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#                                   media_images_size300x200  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#                                   media_images_size320x280  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#                                     media_images_size72x52  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#                                   media_images_size680x392  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#                                 media_images_1_size720x480  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#                                 media_images_1_size600x600  ...  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...  ...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...  ...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...  ...
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...  ...
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...  ...
#
#                                 media_images_3_size680x392 media_total_images  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...                 30
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...                 53
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...                 25
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...                 38
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...                 21
#
#         media_has_video media_has_virtual_tour media_has_brochure  \
# 152700             True                  False              False
# 1442724           False                  False              False
# 1443907            True                  False              False
# 1446982           False                  False              False
# 1527608            True                  False              False
#
#                     media_images_caption media_images_2_caption  \
# 152700                               NaN                    NaN
# 1442724                              NaN                    NaN
# 1443907                              NaN                    NaN
# 1446982                              NaN                    NaN
# 1527608  Apartment's private living room                    NaN
#
#         media_images_3_caption media_images_1_caption media_brochure_url
# 152700                     NaN                    NaN                NaN
# 1442724                    NaN                    NaN                NaN
# 1443907                    NaN                    NaN                NaN
# 1446982                    NaN                    NaN                NaN
# 1527608                    NaN                    NaN                NaN
#
# [5 rows x 41 columns]

# %%
df = join(df, df_medias)

# %% [markdown]
# **ber**

# %%
df_ber = pd.DataFrame([x if type(x) == dict else {} for x in df['ber'].tolist()], index=df.index)
df_ber.head()
# Out:
#          rating code  epi
# id
# 152700   SI_666  NaN  NaN
# 1442724      A2  NaN  NaN
# 1443907      A2  NaN  NaN
# 1446982      NA  NaN  NaN
# 1527608      C2  NaN  NaN

# %%
df_ber.columns = [fix_case(x, 'ber_') for x in df_ber.columns.tolist()]

# %%
df_ber.dropna(axis=1, how='any', thresh=df_ber.shape[0]*.3, inplace=True)

# %%
df_ber.head()
# Out:
#         ber_rating
# id
# 152700      SI_666
# 1442724         A2
# 1443907         A2
# 1446982         NA
# 1527608         C2

# %%
df = join(df, df_ber)

# %% [markdown]
# **point**

# %%
df_point = pd.DataFrame(index=df.index)

# %%
df_point['point_type'] = df['point'].apply(lambda p: p['type'])

# %%
df_point['point_lat'] = df['point'].apply(lambda p: p['coordinates'][0] if p and 'coordinates' in p else np.nan)
df_point['point_long'] = df['point'].apply(lambda p: p['coordinates'][1] if p and 'coordinates' in p else np.nan)

# %%
df = join(df, df_point)

# %% [markdown]
# **page_branding**

# %%
df_page_branding = make_flat(df, 'page_branding')
df_page_branding.head()
# Out:
#                                page_branding_standard_logo  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#                                  page_branding_square_logo  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982                                                NaN
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#         page_branding_background_colour  \
# 152700                          #f4f4f4
# 1442724                         #fee775
# 1443907                         #054573
# 1446982                         #ffffff
# 1527608                         #c6e4d2
#
#                                 page_branding_square_logos  \
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
# 1446982                                               None
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...
#
#                               page_branding_rectangle_logo  page_branding
# 152700   https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...            NaN
# 1442724  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...            NaN
# 1443907  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...            NaN
# 1446982  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...            NaN
# 1527608  https://media.daft.ie/eyJidWNrZXQiOiJtZWRpYW1h...            NaN

# %%
df = join(df, df_page_branding)

# %% [markdown]
# **last_update_date**

# %%
df['last_update_date'] = pd.to_datetime(df['last_update_date'])

# %% [markdown]
# **facilities**

# %%
df_facilities = pd.DataFrame(index=df.index)
df_facilities['facilities_as_list'] = df['facilities'].apply(lambda x: [f['key'] for f in x] if isinstance(x, list) else [])
df_facilities.head()
# Out:
#                                         facilities_as_list
# id
# 152700   [PARKING, CENTRAL_HEATING, CABLE_TELEVISION, W...
# 1442724  [PARKING, CENTRAL_HEATING, CABLE_TELEVISION, W...
# 1443907  [PARKING, CENTRAL_HEATING, CABLE_TELEVISION, W...
# 1446982  [PARKING, CENTRAL_HEATING, CABLE_TELEVISION, W...
# 1527608  [CENTRAL_HEATING, WASHING_MACHINE, DRYER, DISH...

# %%
all_facilities = []
for list_of_facilities in df_facilities['facilities_as_list']:
    for facility in list_of_facilities:
        if facility not in all_facilities:
            all_facilities.append(facility)
all_facilities
# Out:
# ['PARKING',
#  'CENTRAL_HEATING',
#  'CABLE_TELEVISION',
#  'WASHING_MACHINE',
#  'DRYER',
#  'DISHWASHER',
#  'MICROWAVE',
#  'INTERNET',
#  'GARDEN_PATIO_BALCONY',
#  'SERVICED_PROPERTY',
#  'PETS_ALLOWED',
#  'CONCIERGE',
#  'GYM',
#  'COMMUNITY_EVENTS',
#  'CO_WORKING',
#  'WHEELCHAIR_ACCESS',
#  'RESIDENTS_LOUNGE',
#  'ENTERTAINMENT',
#  'LAUNDRY',
#  'ALARM',
#  'SMOKING']

# %%
for facility in all_facilities:
    df_facilities['facility_' + facility.lower()] = df_facilities['facilities_as_list'].apply(lambda f: 1 if facility in f else 0)
df_facilities.head()
# Out:
#                                         facilities_as_list  facility_parking  \
# id
# 152700   [PARKING, CENTRAL_HEATING, CABLE_TELEVISION, W...                 1
# 1442724  [PARKING, CENTRAL_HEATING, CABLE_TELEVISION, W...                 1
# 1443907  [PARKING, CENTRAL_HEATING, CABLE_TELEVISION, W...                 1
# 1446982  [PARKING, CENTRAL_HEATING, CABLE_TELEVISION, W...                 1
# 1527608  [CENTRAL_HEATING, WASHING_MACHINE, DRYER, DISH...                 0
#
#          facility_central_heating  facility_cable_television  \
# id
# 152700                          1                          1
# 1442724                         1                          1
# 1443907                         1                          1
# 1446982                         1                          1
# 1527608                         1                          0
#
#          facility_washing_machine  facility_dryer  facility_dishwasher  \
# id
# 152700                          1               1                    1
# 1442724                         1               1                    1
# 1443907                         1               1                    1
# 1446982                         1               1                    1
# 1527608                         1               1                    1
#
#          facility_microwave  facility_internet  facility_garden_patio_balcony  \
# id
# 152700                    1                  1                              1
# 1442724                   1                  1                              1
# 1443907                   1                  1                              1
# 1446982                   1                  1                              1
# 1527608                   1                  1                              1
#
#          ...  facility_concierge  facility_gym  facility_community_events  \
# id       ...
# 152700   ...                   0             0                          0
# 1442724  ...                   1             1                          1
# 1443907  ...                   1             1                          1
# 1446982  ...                   1             1                          1
# 1527608  ...                   1             0                          1
#
#          facility_co_working  facility_wheelchair_access  \
# id
# 152700                     0                           0
# 1442724                    1                           0
# 1443907                    1                           1
# 1446982                    1                           1
# 1527608                    1                           0
#
#          facility_residents_lounge  facility_entertainment  facility_laundry  \
# id
# 152700                           0                       0                 0
# 1442724                          0                       0                 0
# 1443907                          1                       1                 1
# 1446982                          1                       0                 1
# 1527608                          1                       0                 0
#
#          facility_alarm  facility_smoking
# id
# 152700                0                 0
# 1442724               0                 0
# 1443907               0                 0
# 1446982               0                 0
# 1527608               0                 0
#
# [5 rows x 22 columns]

# %%
df = join(df, df_facilities)

# %% [markdown]
# **non_formatted**

# %%
df_non_formatted = make_flat(df, 'non_formatted')
df_non_formatted.head()
# Out:
#          non_formatted_beds  non_formatted_price non_formatted_section  \
# 152700                  2.0                980.0   residential-to-rent
# 1442724                 NaN               6222.0                   prs
# 1443907                 NaN              10440.0                   prs
# 1446982                 NaN               2710.0                   prs
# 1527608                 NaN               4039.0                   prs
#
#          non_formatted
# 152700             NaN
# 1442724            NaN
# 1443907            NaN
# 1446982            NaN
# 1527608            NaN

# %%
df = join(df, df_non_formatted)

# %% [markdown]
# **property_overview**

# %%
df_property_overview = pd.DataFrame(index=df.index)
df_property_overview['property_overview'] = df['property_overview'].apply(lambda x: {k['label']: k['text'] for k in x} if isinstance(x, list) else np.nan)

# %%
df_property_overview =  make_flat(df_property_overview, 'property_overview').drop(columns=['property_overview'])

# %%
df = join(df, df_property_overview)

# %% [markdown]
# ### Drop columns with no sufficient data

# %% [markdown]
# Drop columns with no values

# %%
df = df.dropna(axis=1, how='all')

# %% [markdown]
# Drop columns with less than 30% of data

# %%
df.dropna(axis=1, how='any', thresh=df.shape[0]*.3, inplace=True)

# %% [markdown]
# Convert dtypes

# %%
df = df.convert_dtypes()

# %%
df.to_csv('data/daft.csv')
